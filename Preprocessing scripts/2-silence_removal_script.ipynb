# %%
import numpy as np
import matplotlib.pyplot as plt
from pydub.silence import split_on_silence
import wave
import os

# %%
# shows the sound waves
def visualize(path: str,sil=None):
    raw = wave.open(path)
    signal = raw.readframes(-1)
    signal = np.frombuffer(signal, dtype ="int16")
    f_rate = raw.getframerate()
    time = np.linspace(
        0, # start
        len(signal) / f_rate,
        num = len(signal)
    )
    plt.figure(1)
    plt.title("Sound Wave")
    plt.xlabel("Time")
    plt.plot(time, signal)
    if sil:
        for i in sil:
            plt.axvline(x=i[0], color='red')
            plt.axvline(x=i[1], color='red')
    plt.show()

# %%
google_drive = False
src_directory_path = "../Datasets"
destination_directory = "../Datasets_noise_removed"
if google_drive:
    src_directory_path = '/content/drive/MyDrive/thesis_models/' + src_directory_path
    destination_directory = '/content/drive/MyDrive/thesis_models/' + destination_directory

# %%
# if not os.path.exists(destination_directory):
#     os.makedirs(destination_directory)
#     print(f"Directory '{destination_directory}' created successfully.")
# else:
#     print(f"Directory '{destination_directory}' already exists.")

# %%
from pydub import AudioSegment
from pydub.silence import split_on_silence
import os
import glob

# %%
file_names = glob.glob(os.path.join(src_directory_path, "**/*.wav"), recursive=True)
file_names
# Out:
# ['../Datasets\\Environment 1\\Testing\\Abdelrahman.wav',
#  '../Datasets\\Environment 1\\Testing\\Omar.wav',
#  '../Datasets\\Environment 1\\Testing\\Reem.wav',
#  '../Datasets\\Environment 1\\Testing\\Renad.wav',
#  '../Datasets\\Environment 1\\Testing\\Sherif.wav',
#  '../Datasets\\Environment 1\\Testing\\Youssef.wav',
#  '../Datasets\\Environment 1\\Training\\Abdelrahman.wav',
#  '../Datasets\\Environment 1\\Training\\Omar.wav',
#  '../Datasets\\Environment 1\\Training\\Reem.wav',
#  '../Datasets\\Environment 1\\Training\\Renad.wav',
#  '../Datasets\\Environment 1\\Training\\Sherif.wav',
#  '../Datasets\\Environment 1\\Training\\Youssef.wav',
#  '../Datasets\\Environment 2\\Abdelrahman\\A_ 10.wav',
#  '../Datasets\\Environment 2\\Abdelrahman\\A_ 2.wav',
#  '../Datasets\\Environment 2\\Abdelrahman\\A_ 4.wav',
#  '../Datasets\\Environment 2\\Abdelrahman\\A_ 5.wav',
#  '../Datasets\\Environment 2\\Abdelrahman\\A_ 7.wav',
#  '../Datasets\\Environment 2\\Abdelrahman\\A_ 8.wav',
# ...

# %%
import os
from pydub import AudioSegment
from pydub.silence import split_on_silence

audio_format = "wav"

for file_path in file_names:
    full_file_path = os.path.join(src_directory_path, file_path)
    
    sound = AudioSegment.from_file(full_file_path, format=audio_format)
    
    audio_chunks = split_on_silence(
        sound,
        min_silence_len=1000,
        silence_thresh=-50,
        keep_silence=50
    )
    
    combined = AudioSegment.empty()
    for chunk in audio_chunks:
        combined += chunk
    
    combined.export(full_file_path, format=audio_format)
    print(f"Processed and exported: {full_file_path}")
# Out:
# Processed and exported: ../Datasets\../Datasets\Environment 1\Testing\Abdelrahman.wav
# Processed and exported: ../Datasets\../Datasets\Environment 1\Testing\Omar.wav
# Processed and exported: ../Datasets\../Datasets\Environment 1\Testing\Reem.wav
# Processed and exported: ../Datasets\../Datasets\Environment 1\Testing\Renad.wav
# Processed and exported: ../Datasets\../Datasets\Environment 1\Testing\Sherif.wav
# Processed and exported: ../Datasets\../Datasets\Environment 1\Testing\Youssef.wav
# Processed and exported: ../Datasets\../Datasets\Environment 1\Training\Abdelrahman.wav
# Processed and exported: ../Datasets\../Datasets\Environment 1\Training\Omar.wav
# Processed and exported: ../Datasets\../Datasets\Environment 1\Training\Reem.wav
# Processed and exported: ../Datasets\../Datasets\Environment 1\Training\Renad.wav
# Processed and exported: ../Datasets\../Datasets\Environment 1\Training\Sherif.wav
# ...

# %%
stop here
# Out:
#   Cell In[32], line 1
#     stop here
#          ^
# SyntaxError: invalid syntax

# %%
combined
# Out:
#                     <audio controls>
#                         <source src="data:audio/mpeg;base64,..." type="audio/mpeg"/>
#                         Your browser does not support the audio element.
#                     </audio>

# %%
visualize(file_path)

# %%
visualize(f'{destination_directory}/{file_name}')

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_131714/903443131.py in <module>
#      33 # Example usage
#      34 audio_file = "training/Y_1.wav"
# ---> 35 vad_segments = voice_activity_detection(audio_file)
#      36
#      37 print("Voice Activity Segments (in milliseconds):")
#
# /tmp/ipykernel_131714/903443131.py in voice_activity_detection(audio_file, threshold, min_silence)
#      19         if energy > threshold:
#      20             silence = 0
# ---> 21             if not voice_segments or i - voice_segments[-1][1] > min_silence:
#      22                 voice_segments.append([i * frame_size, None])
#      23         else:
#
# TypeError: unsupported operand type(s) for -: 'int' and 'NoneType'

# %%
from vad import EnergyVAD

vad = EnergyVAD(
    sample_rate = 16000,
    frame_length = 25, # in milliseconds
    frame_shift = 20, # in milliseconds
    energy_threshold = 0.05, # you may need to adjust this value
    pre_emphasis = 0.95,
) # default values are used here

voice_activity = vad(audio) # returns a boolean array indicating whether a frame is speech or not

# you can also use the following method to get the audio file with only speech
# speech_signal is a numpy array of the same shape as audio
speech_signal = vad.apply_vad(audio)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_131714/3587433268.py in <module>
#      12 ) # default values are used here
#      13
# ---> 14 voice_activity = vad(audio) # returns a boolean array indicating whether a frame is speech or not
#      15
#      16 # you can also use the following method to get the audio file with only speech
#
# ~/.local/lib/python3.10/site-packages/vad/energy_vad.py in __call__(self, waveform)
#      29         '''
#      30
# ---> 31         new_waveform, is_stereo = self._convert_to_mono_if_needed(waveform)
#      32
#      33         # Pre-emphasis
#
# ~/.local/lib/python3.10/site-packages/vad/energy_vad.py in _convert_to_mono_if_needed(self, waveform)
#     109             bool: True if the signal was stereo, False otherwise
#     110         '''
# --> 111         if waveform.ndim == 2 and waveform.shape[0] == 2:
# ...
